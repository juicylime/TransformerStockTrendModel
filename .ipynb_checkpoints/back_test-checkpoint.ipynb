# %% [markdown]
# This notebook is used to back test the model we developed to predict stock trend predictions.

# %% [markdown]
# ### Imports

# %%
import yfinance as yf
import backtrader as bt
import pandas as pd
import pandas_ta as ta
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import os
import json

from fetch_stock_data import get_stock_data
from normalize_data import standardize_stock_data
from trendformer import transformer_model, feature_size, d_model, seq_length, dropout_rate, num_heads, num_layers, dff

# %% [markdown]
# ### Pull market data for model -30 days from start day of simulation

# %%
symbol = 'AMZN'
normalized_params_path = 'G:/StockData/normalized_master_datasets/abs_normalized_parameters.json'

start_date = (datetime.now() - timedelta(days=150)).strftime('%Y-%m-%d')
end_date = datetime.now().strftime('%Y-%m-%d')

stock_data = get_stock_data(start_date, end_date, {symbol:[]})

with open(normalized_params_path, 'r') as file:
    normalized_params = json.load(file)

stock_data, _ = standardize_stock_data(stock_data, normalized_params)

dates = stock_data[symbol]

features_to_keep = ['week_day', 'Open', 'High', 'Low', 'Close', 'Volume','SMA_30', 'SMA_40', 'EMA_10', 'EMA_30', 'MACDh_12_26_9', 'RSI_10', 'BBP_5_2.0', 'avgTradingVolume', 'STOCHk_14_3_3', '52_week_high', '52_week_low', 'NASDAQ_Close', 'STOCHd_14_3_3', 'ADX_14', 'DMP_14', 'DMN_14', 'ISA_9', 'ISB_26', 'ITS_9', 'IKS_26', 'PSAR_combined']

stock_data = {date: {key: value for key, value in sorted(data.items()) if key in features_to_keep} for date, data in dates.items()}
# Out:
# Fetching data for AMZN...

# %% [markdown]
# ### We need to pull intraday market data into a CSV for backtrader

# %%
def fetch_and_save_intraday_data(symbol, interval='1d'):
    # Create the subdirectory if it doesn't exist
    if not os.path.exists('historical_intraday_market_data'):
        os.makedirs('historical_intraday_market_data')
    
    # Calculate start and end dates for the last 60 days
    end = datetime.now()
    start = end - timedelta(days=59)

    # Fetch the intraday market data
    data = yf.download(symbol, start=start, end=end, interval=interval)
    
    # Save the data to a CSV file
    filename = f'historical_intraday_market_data/{symbol}_{interval}.csv'
    data.to_csv(filename)
    
    print(f'Intraday market data for {symbol} saved to {filename}')

fetch_and_save_intraday_data(symbol, interval='2m')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Intraday market data for AMZN saved to historical_intraday_market_data/AMZN_2m.csv

# %% [markdown]
# ### Creating model and load weights

# %%
# Create the transformer model
model = transformer_model(seq_length, feature_size, d_model, num_heads, dff, num_layers, dropout_rate)

# Load the weights
model.load_weights('model_weights\model_weights.h5')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30, 27)]     0           []
#
#  dense (Dense)                  (None, 30, 512)      14336       ['input_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 30, 512)     0           ['dense[0][0]']
#  mbda)
#
#  encoder_layer_1 (Functional)   (None, None, 512)    8928768     ['tf.__operators__.add_1[0][0]']
#
#  encoder_layer_2 (Functional)   (None, None, 512)    8928768     ['encoder_layer_1[0][0]']
#
#  encoder_layer_3 (Functional)   (None, None, 512)    8928768     ['encoder_layer_2[0][0]']
#
#  encoder_layer_4 (Functional)   (None, None, 512)    8928768     ['encoder_layer_3[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 30, 1)       0           ['input_1[0][0]']
#  ingOpLambda)
#
#  encoder_layer_5 (Functional)   (None, None, 512)    8928768     ['encoder_layer_4[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 30, 512)     0           ['tf.__operators__.getitem[0][0]'
#  da)                                                             ]
#
#  encoder_layer_6 (Functional)   (None, None, 512)    8928768     ['encoder_layer_5[0][0]']
#
#  decoder_layer_1 (Functional)   (None, None, 512)    17331200    ['tf.__operators__.add[0][0]',
#                                                                   'encoder_layer_6[0][0]']
#
#  decoder_layer_2 (Functional)   (None, None, 512)    17331200    ['decoder_layer_1[0][0]',
#                                                                   'encoder_layer_6[0][0]']
#
#  decoder_layer_3 (Functional)   (None, None, 512)    17331200    ['decoder_layer_2[0][0]',
#                                                                   'encoder_layer_6[0][0]']
#
#  decoder_layer_4 (Functional)   (None, None, 512)    17331200    ['decoder_layer_3[0][0]',
#                                                                   'encoder_layer_6[0][0]']
#
#  decoder_layer_5 (Functional)   (None, None, 512)    17331200    ['decoder_layer_4[0][0]',
#                                                                   'encoder_layer_6[0][0]']
#
#  decoder_layer_6 (Functional)   (None, None, 512)    17331200    ['decoder_layer_5[0][0]',
#                                                                   'encoder_layer_6[0][0]']
#
#  lambda (Lambda)                (None, 512)          0           ['decoder_layer_6[0][0]']
#
#  dense_25 (Dense)               (None, 1)            513         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 157,574,657
# Trainable params: 157,574,657
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def backtest(csv_file, strategy):
    # Read the CSV file into a pandas dataframe
    df = pd.read_csv(csv_file)

    # Convert the 'Datetime' column to datetime format
    df['Datetime'] = pd.to_datetime(df['Datetime'])

    # Create a backtrader data feed
    data = bt.feeds.PandasData(dataname=df, datetime='Datetime', open='Open', high='High', low='Low', close='Close', volume='Volume')
    # Create a backtrader Cerebro instance
    cerebro = bt.Cerebro()

    # Add the data feed to the Cerebro instance
    cerebro.adddata(data)

    # Add the SMA strategy to the Cerebro instance
    cerebro.addstrategy(strategy, model)

    cerebro.addobserver(bt.observers.BuySell)
    cerebro.addobserver(bt.observers.Value)

    # Set the initial capital
    cerebro.broker.setcash(100000)

    # Run the backtest
    results = cerebro.run(stdstats=False)

    result = results[0]

    # %matplotlib ipympl
    # Extract the DateTime and Close columns from the dataframe
    x = range(len(df['Datetime']))
    y = df['Close']

    # Create a new figure with extended width
    plt.figure(figsize=(12, 6))
    
    # Plot the stock prices
    plt.plot(x, y, color='black', label='Stock')

    
    plt.scatter(result.trades['buy']['date'], result.trades['buy']['price'],s=100, color='green', label='Buy', zorder=3)
    plt.scatter(result.trades['sell']['date'], result.trades['sell']['price'],s=100, color='red', label='Sell', zorder=2)

    # Set the X-axis label
    plt.xlabel('Time (2 minute tick interval)')

    # Set the Y-axis label
    plt.ylabel('Stock Price')

    # Display the plot
    plt.show()

    # Plot portfolio value
    plt.figure(figsize=(12, 6))

    # Plot the stock prices
    plt.plot(result.total_value_of_portfolio['date'], result.total_value_of_portfolio['value'], color='orange', label='Portfolio Value')

    # Set the X-axis label
    plt.xlabel('Time (2 minute tick interval)')

    # Set the Y-axis label
    plt.ylabel('Portfolio Value')
    
    # Display the plot
    plt.show()

    # Print the final portfolio value
    print('Final Portfolio Value:', cerebro.broker.getvalue())

# %% [markdown]
# ### Trendformer Strategy

# %%
class TrendformerStrategy(bt.Strategy):
        def __init__(self, model):
            self.model = model
            self.current_date = None
            self.past_30_days = {}
            self.buy_price = None
            self.is_open = False
            self.prediction = None
            self.last_day_sma_30 = None
            self.size_of_order = None

            # List of trades. Type: {date, price}
            self.trades = {'buy': {'date': [], 'price': []}, 'sell': {'date': [], 'price': []}}
            self.total_value_of_portfolio = {'date': [], 'value': []}
            # Keep track of days
            self.day = 0

        def next(self):
            
            # Get the current iteration date
            current_date = self.data.datetime.datetime()

            # Convert current date to string in format YYYY-MM-DD
            current_date_str = current_date.strftime('%Y-%m-%d')

            if self.current_date != current_date_str and current_date_str in stock_data:
                self.current_date = current_date_str

                # Get the keys (dates) of the stock data as a list
                dates = list(stock_data.keys())

                # Find the index of the current date
                current_date_index = dates.index(current_date_str)

                # Get the 30 dates before the current date, excluding the current date
                last_30_dates = dates[max(0, current_date_index - 30):current_date_index]

                # Get the stock data for the last 30 dates
                past_30_days = {date: stock_data[date] for date in last_30_dates}

                self.past_30_days = past_30_days

                # Get the SMA_30 value of the last day in the past_30_days array
                self.last_day_sma_30 = self.past_30_days[last_30_dates[-1]]['SMA_30']
                # print(f"SMA_30 value |of the last day: {last_day_sma_30}")

                 # Convert the past_30_days data to a numpy array
                past_30_days_data = np.array([list(day.values()) for day in self.past_30_days.values()])

                # Add an extra dimension to represent the batch size
                past_30_days_data = np.expand_dims(past_30_days_data, axis=0)

                # Now you can pass this data into your model
                self.prediction = self.model.predict(past_30_days_data, verbose=0)
                self.prediction = self.prediction[0][0]

                print(f"Prediction: {self.prediction}")
                print(f"Prediction with Confidence: {self.last_day_sma_30*0.98}")
                print(f"Last day SMA_30: {self.last_day_sma_30}\n")
                # If the prediction is above the sma 30 value buy
                if self.prediction > self.last_day_sma_30 and self.is_open == False:

                    # Get the current price
                    self.buy_price = self.data.close[0]

                    # Get the current cash
                    cash1 = self.broker.getcash()
                    print(f"broker Cash {self.broker.getcash()}")

                    # Calculate the number of shares to buy
                    self.size_of_order = cash1 // self.buy_price
                    print(f"Value before execution: {self.broker.getvalue()}")
                    self.buy(size=self.size_of_order,price=self.data.close[0])
                    self.is_open = True
                    print(f"Buy at {self.data.close[0]} because prediction is above SMA_30 value")
                    print(f"Current Portfoloio Value after buying {self.broker.getcash()} ")

                    self.add_trade('buy', self.day, self.data.close[0])
                
                
      
            # We want to sell if the price is 1% above the buy price. Otherwise we just wait it out and hope it goes up.
            if self.prediction < self.last_day_sma_30 and self.is_open == True and self.data.close[0] > self.buy_price*1.05:
                print(f"Cash price {self.broker.getcash()}")
                # self.sell(size=self.size)
                self.close()
                self.is_open = False
                print(f"Sell at {self.data.close[0]} to lock in profit. Prediction is below SMA_30 value and we are above buy price")
                # Print current portfol value
                print(f"Current portfolio value: {self.broker.getvalue()}")

                self.add_trade('sell', self.day, self.data.close[0])
                
            # Tick by tick sell logic
            if self.is_open == True:
                # Stop loss
                # if self.data.close[0] < self.buy_price * 0.99:
                #     # self.sell(size=self.size)
                #     self.close()
                #     self.is_open = False
                #     print(f"Sell at {self.data.close[0]} to stop loss")
                #     print(f"Current portfolio value: {self.broker.getvalue()}")
                #     self.loss_count += 1
                # Sell if price is 5% above buy price
                if self.data.close[0] > self.buy_price * 1.05:
                    # self.sell(size=self.size,price=self.data.close[0])
                    self.close()
                    self.is_open = False
                    print(f"Sell at {self.data.close[0]} to lock in profit")
                    print(f"Current portfolio value: {self.broker.getvalue()}")

                    self.add_trade('sell', self.day, self.data.close[0])

            self.total_value_of_portfolio['date'].append(self.day)
            self.total_value_of_portfolio['value'].append(self.broker.getvalue())
            self.day+=1

        def add_trade(self, type='buy', date=0, price=1):
            self.trades[type]['date'].append(date)
            self.trades[type]['price'].append(price)
                    
backtest(f'historical_intraday_market_data/{symbol}_2m.csv', TrendformerStrategy)
# Out:
# Prediction: 1.4698034524917603
# Prediction with Confidence: 1.3692436386361149
# Last day SMA_30: 1.3971873863633826
#
# broker Cash 100000.0
# Value before execution: 100000.0
# Buy at 140.25999450683594 because prediction is above SMA_30 value
# Current Portfoloio Value after buying 100000.0
# Prediction: 1.471550464630127
# Prediction with Confidence: 1.3782829545479738
# Last day SMA_30: 1.4064111781101774
#
# Prediction: 1.4921497106552124
# Prediction with Confidence: 1.3875098031982243
# Last day SMA_30: 1.4158263297941065
#
# Prediction: 1.5026780366897583
# Prediction with Confidence: 1.3970849450380423
# Last day SMA_30: 1.42559688269188
#
# Prediction: 1.4961793422698975
# Prediction with Confidence: 1.4048114949891934
# Last day SMA_30: 1.4334811173359117
#
# Sell at 147.5413055419922 to lock in profit
# Current portfolio value: 105162.93432617188
# Prediction: 1.5142865180969238
# Prediction with Confidence: 1.4127845265841643
# Last day SMA_30: 1.4416168638613922
#
# broker Cash 105163.28198242188
# Value before execution: 105163.28198242188
# Buy at 146.25 because prediction is above SMA_30 value
# Current Portfoloio Value after buying 105163.28198242188
# Prediction: 1.5219874382019043
# Prediction with Confidence: 1.4205057212602727
# Last day SMA_30: 1.449495633939054
#
# Prediction: 1.5337576866149902
# Prediction with Confidence: 1.4301183663773722
# Last day SMA_30: 1.4593044554871146
#
# Prediction: 1.5342563390731812
# Prediction with Confidence: 1.4378770643307623
# Last day SMA_30: 1.4672214942150636
#
# Prediction: 1.5394288301467896
# Prediction with Confidence: 1.4458340219246135
# Last day SMA_30: 1.4753408386985853
#
# Prediction: 1.5469213724136353
# Prediction with Confidence: 1.4554573775917978
# Last day SMA_30: 1.4851605893793856
#
# Prediction: 1.5626376867294312
# Prediction with Confidence: 1.4654397410866309
# Last day SMA_30: 1.4953466745781947
#
# Prediction: 1.5579806566238403
# Prediction with Confidence: 1.475979355697589
# Last day SMA_30: 1.5061013833648869
#
# Prediction: 1.5755051374435425
# Prediction with Confidence: 1.4868672594101184
# Last day SMA_30: 1.5172114891939985
#
# Prediction: 1.575138807296753
# Prediction with Confidence: 1.4954189795733686
# Last day SMA_30: 1.5259377342585394
#
# Prediction: 1.5939698219299316
# Prediction with Confidence: 1.5090770812173895
# Last day SMA_30: 1.5398745726708056
#
# Prediction: 1.607343077659607
# Prediction with Confidence: 1.5239997186427667
# Last day SMA_30: 1.555101753717109
#
# Prediction: 1.607730746269226
# Prediction with Confidence: 1.533724885855699
# Last day SMA_30: 1.5650253937303051
#
# Prediction: 1.6199841499328613
# Prediction with Confidence: 1.5416389685452416
# Last day SMA_30: 1.573100988311471
#
# Prediction: 1.6330543756484985
# Prediction with Confidence: 1.550078162524663
# Last day SMA_30: 1.581712410739452
#
# Prediction: 1.6341487169265747
# Prediction with Confidence: 1.5556614251159613
# Last day SMA_30: 1.5874096174652665
#
# Prediction: 1.6487849950790405
# Prediction with Confidence: 1.5620377017411264
# Last day SMA_30: 1.593916022184823
#
# Sell at 153.5800018310547 to lock in profit
# Current portfolio value: 105163.28198242188
# Prediction: 1.6693317890167236
# Prediction with Confidence: 1.5703268662594376
# Last day SMA_30: 1.6023743533259567
#
# broker Cash 105163.28198242188
# Value before execution: 105163.28198242188
# Buy at 154.8300018310547 because prediction is above SMA_30 value
# Current Portfoloio Value after buying 105163.28198242188
# Prediction: 1.67927086353302
# Prediction with Confidence: 1.5778551565701273
# Last day SMA_30: 1.6100562822144155
#
# Prediction: 1.6757534742355347
# Prediction with Confidence: 1.5828972338704272
# Last day SMA_30: 1.6152012590514564
#
# Prediction: 1.684722900390625
# Prediction with Confidence: 1.5891984957650378
# Last day SMA_30: 1.6216311181275895
#
# Prediction: 1.6915957927703857
# Prediction with Confidence: 1.5960677275018507
# Last day SMA_30: 1.6286405382671947
#
# Prediction: 1.6943633556365967
# Prediction with Confidence: 1.6013455758958857
# Last day SMA_30: 1.6340260978529446
#
# Prediction: 1.7000373601913452
# Prediction with Confidence: 1.6071056606754903
# Last day SMA_30: 1.6399037353831534
#
# Prediction: 1.7018240690231323
# Prediction with Confidence: 1.611167191203531
# Last day SMA_30: 1.6440481542893175
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Final Portfolio Value: 101561.1919555664

# %% [markdown]
# ### SMA Strategy

# %%
class SMAStrategy(bt.Strategy):
    params = (
        ('sma_period', 60),  # Period for the SMA
    )

    def __init__(self, model):
        # self.sma = bt.indicators.SimpleMovingAverage(period=60)
        self.sma = bt.indicators.SimpleMovingAverage(
            self.data.close, period=self.params.sma_period
        )
        self.size = None
        self.is_open = False
        # List of trades. Type: {date, price}
        self.trades = {'buy': {'date': [], 'price': []}, 'sell': {'date': [], 'price': []}}
        self.total_value = {'date': [], 'value': []}
        # Keep track of days
        self.day = 0

    def next(self):
        if self.data.close[0] > self.sma[0] and self.is_open == False:
            # Get the current price
            self.buy_price = self.data.close[0]

            # Get the current cash
            cash = self.broker.getcash()

            # Calculate the number of shares to buy
            self.size = cash // self.buy_price

            self.buy(size=self.size)
            self.is_open = True

            self.add_trade('buy', self.day, self.data.close[0])

            

        if self.data.close[0] < self.sma[0] and self.is_open == True:
            # self.sell(size=self.size)
            self.close()
            self.is_open = False
            self.add_trade('sell', self.day, self.data.close[0])

        # # Tick by tick sell logic
        # if self.is_open == True:
        #     # Stop loss
        #     if self.data.close[0] < self.buy_price * 0.95:
        #         self.sell(size=self.size)
        #         self.is_open = False
        #         print(f"Sell at {self.data.close[0]} to stop loss")
        #         print(f"Current portfolio value: {self.broker.getvalue()}")

            # Sell if price is 5% above buy price
            # if self.data.close[0] > self.buy_price * 1.20:
            #     # self.sell(size=self.size)
            #     self.close()
            #     self.is_open = False
            #     print(f"Sell at {self.data.close[0]} to lock in profit")
            #     print(f"Current portfolio value: {self.broker.getvalue()}")
            
        self.total_value['date'].append(self.day)
        self.total_value['value'].append(self.broker.getvalue())
        self.day+=1

    def add_trade(self, type='buy', date=0, price=1):
        self.trades[type]['date'].append(date)
        self.trades[type]['price'].append(price)


backtest(f'historical_intraday_market_data/{symbol}_2m.csv', SMAStrategy)
# Out:
# [1, 8, 11, 55, 58, 64, 66, 71, 111, 113, 122, 127, 130, 133, 217, 236, 296, 307, 312, 332, 337, 358, 462, 499, 525, 527, 556, 561, 564, 567, 570, 597, 603, 650, 667, 677, 714, 719, 798, 800, 837, 873, 987, 1046, 1049, 1079, 1082, 1084, 1134, 1136, 1188, 1205, 1244, 1252, 1306, 1333, 1338, 1349, 1361, 1386, 1549, 1599, 1741, 1750, 1780, 1784, 1815, 1845, 1858, 1907, 1940, 1945, 1957, 1985, 2057, 2142, 2151, 2187, 2324, 2340, 2401, 2419, 2457, 2474, 2525, 2529, 2542, 2574, 2638, 2644, 2739, 2794, 2867, 2869, 2876, 2881, 2886, 2902, 2912, 2915, 3042, 3048, 3062, 3102, 3105, 3109, 3112, 3161, 3214, 3222, 3226, 3251, 3253, 3261, 3347, 3353, 3489, 3531, 3537, 3547, 3551, 3561, 3619, 3689, 3775, 3777, 3830, 3861, 3879, 4036, 4039, 4079, 4083, 4104, 4121, 4133, 4145, 4159, 4181, 4183, 4194, 4231, 4233, 4235, 4319, 4328, 4424, 4429, 4438, 4456, 4468, 4523, 4628, 4638, 4667, 4681, 4687, 4689, 4693, 4767, 4805, 4876, 4903, 4905, 5049, 5077, 5113, 5174, 5176, 5188, 5217, 5289, 5298, 5330, 5334, 5358, 5383, 5399, 5403, 5412, 5433, 5508, 5593, 5692, 5751, 5807]
# [137.86000061035156, 138.02999877929688, 138.10000610351562, 138.23989868164062, 138.2550048828125, 138.3699951171875, 138.36000061035156, 138.4600067138672, 138.47000122070312, 138.4600067138672, 138.5, 138.5399932861328, 138.5800018310547, 138.59500122070312, 136.10499572753906, 135.98500061035156, 136.35000610351562, 136.36000061035156, 136.3524932861328, 136.5800018310547, 136.75999450683594, 136.85000610351562, 138.0800018310547, 138.05499267578125, 137.9600067138672, 138.0800018310547, 138.27000427246094, 138.3123016357422, 138.27000427246094, 138.2550048828125, 138.28500366210938, 138.22999572753906, 138.1999969482422, 138.30999755859375, 138.52099609375, 138.44000244140625, 138.55499267578125, 138.56500244140625, 140.22000122070312, 140.24000549316406, 140.14500427246094, 140.13499450683594, 138.0500030517578, 138.25999450683594, 138.38999938964844, 138.1199951171875, 138.07859802246094, 138.0800018310547, 138.2949981689453, 138.3000030517578, 138.19000244140625, 138.15499877929688, 137.77499389648438, 137.8300018310547, 138.07000732421875, 138.05990600585938, 138.0749969482422, 138.1199951171875, 138.00999450683594, 138.11000061035156, 136.94500732421875, 136.89999389648438, 133.1649932861328, 133.11000061035156, 133.13499450683594, 133.19000244140625, 133.14999389648438, 132.8800048828125, 132.5800018310547, 133.05999755859375, 133.1699981689453, 133.16000366210938, 133.1649932861328, 133.1750030517578, 129.88900756835938, 130.39999389648438, 130.19500732421875, 130.6208953857422, 132.0500030517578, 132.00140380859375, 132.75, 132.6199951171875, 132.4499969482422, 132.33799743652344, 131.99000549316406, 132.03500366210938, 131.97000122070312, 138.00999450683594, 138.24000549316406, 138.30999755859375, 138.6699981689453, 137.85000610351562, 136.53469848632812, 136.52499389648438, 136.4600067138672, 136.44000244140625, 136.45010375976562, 136.39500427246094, 136.4499969482422, 136.53500366210938, 133.8300018310547, 133.81500244140625, 133.88499450683594, 134.0850067138672, 134.0500030517578, 134.08999633789062, 134.07000732421875, 134.36000061035156, 133.9199981689453, 133.77499389648438, 133.83999633789062, 133.68499755859375, 133.7100067138672, 133.72000122070312, 133.72000122070312, 133.64999389648438, 133.42999267578125, 133.89999389648438, 133.8699951171875, 133.9600067138672, 134.02999877929688, 134.10049438476562, 132.48500061035156, 132.02000427246094, 133.49000549316406, 133.6199951171875, 133.38999938964844, 133.06500244140625, 133.0850067138672, 137.25770568847656, 137.4149932861328, 137.6300048828125, 137.62069702148438, 137.63499450683594, 137.63499450683594, 138.77000427246094, 138.10000610351562, 137.9499053955078, 137.94000244140625, 137.89999389648438, 137.98500061035156, 137.8199005126953, 137.93499755859375, 137.86500549316406, 138.44500732421875, 140.85000610351562, 142.15029907226562, 142.11000061035156, 142.10499572753906, 142.08999633789062, 142.10000610351562, 141.22999572753906, 141.4600067138672, 141.3000030517578, 141.33009338378906, 141.42999267578125, 141.35000610351562, 141.34500122070312, 141.3350067138672, 142.63099670410156, 142.4499969482422, 142.64999389648438, 142.60000610351562, 142.59500122070312, 142.72000122070312, 142.63999938964844, 142.77999877929688, 141.61500549316406, 141.6199951171875, 141.5509033203125, 141.49000549316406, 141.40499877929688, 141.31500244140625, 141.3350067138672, 141.35629272460938, 141.4199981689453, 141.4499969482422, 141.52999877929688, 141.49000549316406, 141.51019287109375, 141.48500061035156, 141.40769958496094, 140.3300018310547, 140.97999572753906, 138.6999969482422, 139.1199951171875]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Final Portfolio Value: 95918.7163848877

# %% [markdown]
# ### Buy and Hold Strategy

# %%
class BuyAndHoldStrategy(bt.Strategy):
    def __init__(self, model):
        pass

    def next(self):
        if not self.position:
            self.buy()

backtest(f'historical_intraday_market_data/{symbol}_2m.csv', BuyAndHoldStrategy)
# Out:
# Final Portfolio Value: 100013.7799987793

# %% [markdown]
# ### Moving Average Crossover Strategy

# %%
class MovingAverageCrossoverStrategy(bt.Strategy):
    params = (
        ('short_period', 50),  # Period for the short-term moving average
        ('long_period', 200),  # Period for the long-term moving average
    )

    def __init__(self, model):
        self.short_ma = bt.indicators.SimpleMovingAverage(
            self.data.close, period=self.params.short_period
        )
        self.long_ma = bt.indicators.SimpleMovingAverage(
            self.data.close, period=self.params.long_period
        )
        self.size = None
        self.is_open = False
        self.buy_price = None

    def next(self):
        if self.short_ma[0] > self.long_ma[0] and self.short_ma[-1] < self.long_ma[-1] and self.is_open == False:
            # Get the current price
            self.buy_price = self.data.close[0]

            # Get the current cash
            cash = self.broker.getcash()

            # Calculate the number of shares to buy
            self.size = cash // self.buy_price

            self.buy(size=self.size)
            self.is_open = True
        if self.short_ma[0] < self.long_ma[0] and self.short_ma[-1] > self.long_ma[-1] and self.is_open == True:
            self.sell(size=self.size)
            self.is_open = False
        # Tick by tick sell logic
        if self.is_open == True:
            
            # Stop loss
            if self.data.close[0] < self.buy_price * 0.95:
                self.sell(size=self.size)
                self.is_open = False
                print(f"Sell at {self.data.close[0]} to stop loss")
                print(f"Current portfolio value: {self.broker.getvalue()}")

            # Sell if price is 5% above buy price
            elif self.data.close[0] > self.buy_price * 1.05:
                self.sell(size=self.size)
                self.is_open = False
                print(f"Sell at {self.data.close[0]} to lock in profit")
                print(f"Current portfolio value: {self.broker.getvalue()}")

backtest(f'historical_intraday_market_data/{symbol}_2m.csv', MovingAverageCrossoverStrategy)
# Out:
# C:\Users\Aman\AppData\Local\Temp\ipykernel_2764\84711492.py:6: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise a warning unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['Datetime'] = pd.to_datetime(df['Datetime'])
# Sell at 223.37879943847656 to lock in profit
# Current portfolio value: 102356.50872802731
# Sell at 250.48019409179688 to lock in profit
# Current portfolio value: 102819.03742980948
# Final Portfolio Value: 103777.28096008289

# %% [markdown]
# ### Relative Strength Index (RSI) Strategy

# %%
class RSIStrategy(bt.Strategy):
    params = (
        ('rsi_period', 14),  # Period for the RSI
        ('rsi_buy_threshold', 30),  # RSI threshold for buying
        ('rsi_sell_threshold', 70),  # RSI threshold for selling
    )

    def __init__(self, model):
        self.rsi = bt.indicators.RelativeStrengthIndex(
            self.data.close, period=self.params.rsi_period
        )

    def next(self):
        if self.rsi[0] < self.params.rsi_buy_threshold:
            # Get the current price
            buy_price = self.data.close[0]

            # Get the current cash
            cash = self.broker.getcash()

            # Calculate the number of shares to buy
            self.size = cash // buy_price

            self.buy(size=self.size)
        elif self.rsi[0] > self.params.rsi_sell_threshold:
            self.sell()

backtest(f'historical_intraday_market_data/{symbol}_2m.csv', RSIStrategy)
# Out:
# C:\Users\Aman\AppData\Local\Temp\ipykernel_2764\84711492.py:6: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise a warning unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['Datetime'] = pd.to_datetime(df['Datetime'])
# Final Portfolio Value: 115374.73017883301

# %% [markdown]
# ### MACD Strategy

# %%
class MACDStrategy(bt.Strategy):
    def __init__(self, model):
        self.macd = bt.indicators.MACD(self.data.close)

    def next(self):
        if self.macd.macd[0] > self.macd.signal[0]:
            # Get the current price
            buy_price = self.data.close[0]

            # Get the current cash
            cash = self.broker.getcash()

            # Calculate the number of shares to buy
            self.size = cash // buy_price

            self.buy(size=self.size)
        elif self.macd.macd[0] < self.macd.signal[0]:
            self.sell()

backtest(f'historical_intraday_market_data/{symbol}_2m.csv', MACDStrategy)
# Out:
# C:\Users\Aman\AppData\Local\Temp\ipykernel_2764\84711492.py:6: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise a warning unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['Datetime'] = pd.to_datetime(df['Datetime'])
# Final Portfolio Value: 113779.53253173828

# %% [markdown]
# ### Bollinger Bands Strategy

# %%
class BollingerBandsStrategy(bt.Strategy):
    params = (
        ('bb_period', 20),  # Period for the Bollinger Bands
        ('bb_devfactor', 2),  # Standard deviation factor for the Bollinger Bands
    )

    def __init__(self, model):
        self.bbands = bt.indicators.BollingerBands(
            self.data.close, period=self.params.bb_period, devfactor=self.params.bb_devfactor
        )

    def next(self):
        if self.data.close[0] < self.bbands.lines.bot[0]:
           # Get the current price
            buy_price = self.data.close[0]

            # Get the current cash
            cash = self.broker.getcash()

            # Calculate the number of shares to buy
            self.size = cash // buy_price

            self.buy(size=self.size)
        elif self.data.close[0] > self.bbands.lines.top[0]:
            self.sell()

backtest(f'historical_intraday_market_data/{symbol}_2m.csv', BollingerBandsStrategy)
# Out:
# C:\Users\Aman\AppData\Local\Temp\ipykernel_2764\84711492.py:6: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise a warning unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['Datetime'] = pd.to_datetime(df['Datetime'])
# Final Portfolio Value: 114480.62158203125

# %% [markdown]
# ### Custom Strategy using multiple technical indicators

# %%
class CustomStrategy(bt.Strategy):
    def __init__(self, model):
        self.model = model
        self.indicators = []

        # Add your technical indicators here
        self.indicators.append(bt.indicators.SimpleMovingAverage(self.data.close, period=10))
        self.indicators.append(bt.indicators.ExponentialMovingAverage(self.data.close, period=20))
        self.indicators.append(bt.indicators.RSI(self.data.close, period=14))
        self.indicators.append(bt.indicators.MACD(self.data.close))
        self.indicators.append(bt.indicators.BollingerBands(self.data.close))
        self.size = None

    def next(self):
        buy_signals = 0
        sell_signals = 0

        # Check the signals of each indicator
        for indicator in self.indicators:
            if indicator[0] > indicator[-1]:
                buy_signals += 1
            elif indicator[0] < indicator[-1]:
                sell_signals += 1

        # Buy if 3 of the 5 indicators signal buy
        if buy_signals >= 3 and self.size == None:
            # Get the current price
            buy_price = self.data.close[0]

            # Get the current cash
            cash = self.broker.getcash()

            # Calculate the number of shares to buy
            self.size = cash // buy_price

            self.buy(size=self.size)

        # Sell if 3 of the 5 indicators signal sell
        elif sell_signals >= 3 and self.size != None:
            self.sell(size=self.size)
            self.size = None

backtest(f'historical_intraday_market_data/{symbol}_2m.csv', CustomStrategy)
# Out:
# Final Portfolio Value: -588202.4854907822
